# %% [markdown]
# houseprise-advanced regression techniques

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# !unzip /content/creditcard.csv.zip
# Out:
# Archive:  /content/creditcard.csv.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/creditcard.csv.zip or
#         /content/creditcard.csv.zip.zip, and cannot find /content/creditcard.csv.zip.ZIP, period.

# %%
df = pd.read_csv('/content/creditcard.csv.zip')

# %%
df.head()

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2359/3771845804.py in <cell line: 0>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
#showing statistic details
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2359/734787254.py in <cell line: 0>()
#       1 #showing statistic details
# ----> 2 df.describe()
#
# NameError: name 'df' is not defined

# %%
# identifying dimensions or dataframe
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2359/2002463449.py in <cell line: 0>()
#       1 # identifying dimensions or dataframe
# ----> 2 df.shape
#
# NameError: name 'df' is not defined

# %%
# identifying number of columns
print("no_of columns",df.shape[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2359/1769139683.py in <cell line: 0>()
#       1 # identifying number of columns
# ----> 2 print("no_of columns",df.shape[1])
#
# NameError: name 'df' is not defined

# %%
# identidying number of rows
print("no_of rows",df.shape[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2359/2613450686.py in <cell line: 0>()
#       1 # identidying number of rows
# ----> 2 print("no_of rows",df.shape[0])
#
# NameError: name 'df' is not defined

# %%
# identifying duplicate values
df.duplicated()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2359/1285233753.py in <cell line: 0>()
#       1 # identifying duplicate values
# ----> 2 df.duplicated()
#
# NameError: name 'df' is not defined

# %%
# identifying duplicate sum
df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2359/163695488.py in <cell line: 0>()
#       1 # identifying duplicate sum
# ----> 2 df.duplicated().sum()
#
# NameError: name 'df' is not defined

# %%
# deleting duplicate values
df=df.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2359/934992198.py in <cell line: 0>()
#       1 # deleting duplicate values
# ----> 2 df=df.drop_duplicates()
#
# NameError: name 'df' is not defined

# %%
# checking duplicate removed or not
df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2359/3180032987.py in <cell line: 0>()
#       1 # checking duplicate removed or not
# ----> 2 df.duplicated().sum()
#
# NameError: name 'df' is not defined

# %%
df["Amount"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2359/2090426190.py in <cell line: 0>()
# ----> 1 df["Amount"]
#
# NameError: name 'df' is not defined

# %%
sc=StandardScaler()

# %%
df['Amount']=sc.fit_transform(pd.DataFrame(df['Amount']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2359/512986381.py in <cell line: 0>()
# ----> 1 df['Amount']=sc.fit_transform(pd.DataFrame(df['Amount']))
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df=df.drop(['Time'],axis=1)

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
plt.hist(df['Class'].value_counts())
plt.show()

# %%
plt.pie(df['Class'].value_counts(),labels=['normal','fraud'])
plt.show()

# %%
plt.scatter(df['V1'],df['V2'])
plt.show()

# %%
plt.scatter(df['V1'],df['V2'],c=df['Class'])
plt.show()

# %%
normal=df[df[('Class')]==0]

# %%
normal.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
fraud=df[df[('Class')]==1]

# %%
fraud.head()
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 541  -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 623  -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 4920 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788  0.562320
# 6108 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536 -3.496197
# 6329  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746  1.713445
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 541   1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049 -0.465211
# 623  -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966
# 4920 -0.399147 -0.238253 -1.525412  ... -0.294166 -0.932391  0.172726
# 6108 -0.248778 -0.247768 -4.801637  ...  0.573574  0.176968 -0.436207
# 6329 -0.496358 -1.282858 -2.447469  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28    Amount  Class
# ...

# %%
normal.shape
# Out:
# (283253, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample=normal.sample(n=473)

# %%
normal_sample
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 272339 -0.675840  0.122243 -0.360729 -0.618476  0.530159 -0.526858  1.174543
# 9438   -3.640776  0.740725  0.832858  0.484796 -1.829981  0.372554 -0.743923
# 264536 -0.324969  1.269360  1.214408  2.756707  1.411691  1.088470  0.659218
# 49818   1.315362 -0.207586 -1.118486 -0.745058  1.934506  3.365860 -0.603665
# 179833  2.016461 -1.142666  0.276508 -0.366955 -1.764988 -0.467455 -1.410358
# ...          ...       ...       ...       ...       ...       ...       ...
# 201142  1.653889 -2.254649 -3.173333 -1.543027 -0.213086 -0.723079  0.423499
# 26135  -2.279112  1.698746  1.218542 -0.031516 -1.546018  0.150468 -1.192388
# 151680  2.041904  0.096470 -1.698675  0.453888  0.569248 -0.368454 -0.095714
# 60174   1.313851 -1.132929  0.219158 -1.473782 -1.198424 -0.372259 -0.764947
# 31549  -0.757091 -0.095193  0.946012 -2.733769 -0.747485 -0.245436 -0.746192
#
# ...

# %%
normal.shape
# Out:
# (283253, 30)

# %%
newdf=pd.concat([normal.sample(n=473),fraud],ignore_index=True)

# %%
newdf.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.549495 -1.377498  1.782418 -1.786862  1.058844 -0.635557 -1.250366
# 1 -0.587989  0.768887 -1.287777 -1.037533  2.747174  3.656212  0.277097
# 2 -4.402207 -5.273815  2.461278  0.156687  4.960731 -1.919686 -3.955572
# 3 -0.909364  0.475820  1.108370 -1.154793 -0.322298 -1.120776  0.220907
# 4  2.055202  0.112872 -1.704528  0.434977  0.368631 -0.902517  0.181484
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.374891 -1.018531  0.368811  ...  0.522573  1.053959 -0.152077 -0.788917
# 1  0.977062 -0.209994 -0.349523  ... -0.092407 -0.236957 -0.001823  0.696970
# 2  1.129985  1.415086 -1.169187  ...  0.601201  0.517585  0.819922 -0.959023
# 3 -0.353078 -1.200723  0.229449  ... -0.029829 -0.125383  0.226237  0.298092
# 4 -0.227015  0.527987 -0.375168  ... -0.359872 -0.963560  0.338875  0.561801
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
x=newdf.drop(['Class'],axis=1)

# %%
y=newdf['Class']

# %%
print(y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 941    1
# 942    1
# 943    1
# 944    1
# 945    1
# Name: Class, Length: 946, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=14)

# %%
models=RandomForestClassifier(n_estimators=20,random_state=30)

# %%
models.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=20, random_state=30)

# %%
y_pred=models.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy=accuracy_score(y_test,y_pred)
print(f"Accuracy:{accuracy:.2f}")
# Out:
# Accuracy:0.94
